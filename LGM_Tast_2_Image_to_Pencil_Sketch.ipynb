# %% [markdown]
# <a href="https://colab.research.google.com/github/Ausmita-Biswas/LMVVIP-DataScience/blob/main/LGM_Tast_2_Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread("image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=766x1000 at 0x7F0FFFFB6C10>

# %%
grey = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey)
# Out:
# <PIL.Image.Image image mode=L size=766x1000 at 0x7F0FFFF54850>

# %%
invert = cv2.bitwise_not(grey)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=766x1000 at 0x7F0FFEED9690>

# %%
blur = cv2.GaussianBlur(invert, (21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=766x1000 at 0x7F0FFEEE46D0>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=766x1000 at 0x7F0FFEEE4E10>

# %%
sketch = cv2.divide(grey,invertblur,scale=255.0)
cv2_imshow(sketch)
cv2.imwrite("images.png",sketch)
# Out:
# <PIL.Image.Image image mode=L size=766x1000 at 0x7F0FFEEEB9D0>
# True
